# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
import random

# Número de simulaciones
n = 1000

contador = 0

for _ in range(n):
    dado1 = random.randint(1, 6)
    dado2 = random.randint(1, 6)
    
    suma = dado1 + dado2
    
    # Condición: suma mayor a 7 O suma par
    if suma > 7 or suma % 2 == 0:
        contador += 1

# Probabilidad estimada
probabilidad = contador / n

print("Veces que ocurrió el evento:", contador)
print("Probabilidad estimada:", probabilidad)
# Out:
# Veces que ocurrió el evento: 653
# Probabilidad estimada: 0.653

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
import random

balls = []

for i in range(60):
    if i < 10:
        balls.append("White")
    elif i < 30:
        balls.append("Red")
    else:
        balls.append("Green")

count_white_red = 0
count_same_color = 0

n = 1000

for _ in range(n):
    selected_balls = [random.choice(balls) for _ in range(5)]
    
    white = selected_balls.count("White")
    red = selected_balls.count("Red")
    green = selected_balls.count("Green")
    
    if white == 3 and red == 2:
        count_white_red += 1
    
    if white == 5 or red == 5 or green == 5:
        count_same_color += 1

prob_white_red = count_white_red / n
prob_same_color = count_same_color / n

print("Probabilidad de 3 blancas y 2 rojas:", prob_white_red)
print("Probabilidad de todas del mismo color:", prob_same_color)
# Out:
# Probabilidad de 3 blancas y 2 rojas: 0.005
# Probabilidad de todas del mismo color: 0.035
